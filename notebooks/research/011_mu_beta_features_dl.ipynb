# %%
import numpy as np
from scipy import stats
from scipy.stats import entropy
from pywt import wavedec
from scipy.signal import welch


from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from mne_features.univariate import compute_spect_entropy, compute_wavelet_coef_energy
# https://mne.tools/mne-features/api.html

import mne
from mne.io import concatenate_raws, read_raw_edf
import glob


from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, ShuffleSplit, cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from mne.decoding import CSP, SPoC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from mne.decoding import (
    SlidingEstimator,
    GeneralizingEstimator,
    Scaler,
    cross_val_multiscore,
    LinearModel,
    get_coef,
    Vectorizer,
    CSP,
)
import numpy as np
from mne.preprocessing import ICA

from lightgbm import LGBMClassifier
from xgboost.sklearn import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from utils import preprocess_data


import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Conv1D, MaxPooling1D, Dropout, Flatten, BatchNormalization, Conv2D, DepthwiseConv2D, AveragePooling2D, Activation, SeparableConv2D, SpatialDropout1D
from tensorflow.keras.utils import to_categorical
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
import glob
import numpy as np
from utils import preprocess_data
from mne.preprocessing import ICA
# Out:
# 2023-09-05 23:45:48.233177: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# https://www.researchgate.net/publication/309577320_Motor_Imagery_Classification_Using_Mu_and_Beta_Rhythms_of_EEG_with_Strong_Uncorrelating_Transform_Based_Complex_Common_Spatial_Patterns
#
# https://arxiv.org/ftp/arxiv/papers/1312/1312.2877.pdf

# %%
'''
=========  ===================================
run        task
=========  ===================================
1          Baseline, eyes open
2          Baseline, eyes closed
3, 7, 11   Motor execution: left vs right hand
4, 8, 12   Motor imagery: left vs right hand
5, 9, 13   Motor execution: hands vs feet
6, 10, 14  Motor imagery: hands vs feet
=========  ===================================
'''
raws_train = []
raws_test = []
for ii in range(1, 35):
    subject = f'S{ii:03d}'
    files = glob.glob(f'../../files/{subject}/*.edf')
    for i in [5, 9, 13, 3, 7, 11]:
        current_file = files[i]
        r = read_raw_edf(current_file, preload=True, stim_channel='auto')
        events, _ = mne.events_from_annotations(r)
        if i in [5, 9, 13]:
            new_labels_events = {1:'rest', 2:'T1', 3:'T2'} # action
        elif i in [3, 7, 11]:
            new_labels_events = {1:'rest', 2:'T3', 3:'T4'}
        new_annot = mne.annotations_from_events(events=events, event_desc=new_labels_events, sfreq=r.info['sfreq'], orig_time=r.info['meas_date'])
        r.set_annotations(new_annot)
        if ii < 4:
            raws_test.append(r)
        else:
            raws_train.append(r)
    
raws_train_obj = concatenate_raws(raws_train)
raw_test_obj = concatenate_raws(raws_test)
# Out:
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S001/S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S001/S001R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S001/S001R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S001/S001R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S001/S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S001/S001R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S002/S002R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S002/S002R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S002/S002R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S002/S002R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S002/S002R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S002/S002R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S003/S003R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S003/S003R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S003/S003R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S003/S003R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S003/S003R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S003/S003R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S004/S004R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S004/S004R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S004/S004R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S004/S004R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S004/S004R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S004/S004R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S005/S005R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S005/S005R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S005/S005R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S005/S005R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S005/S005R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S005/S005R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S006/S006R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S006/S006R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S006/S006R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S006/S006R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S006/S006R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S006/S006R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S007/S007R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S007/S007R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S007/S007R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S007/S007R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S007/S007R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S007/S007R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S008/S008R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S008/S008R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S008/S008R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S008/S008R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S008/S008R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S008/S008R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S009/S009R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S009/S009R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S009/S009R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S009/S009R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S009/S009R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S009/S009R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S010/S010R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S010/S010R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S010/S010R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S010/S010R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S010/S010R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S010/S010R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S011/S011R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S011/S011R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S011/S011R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S011/S011R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S011/S011R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S011/S011R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S012/S012R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S012/S012R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S012/S012R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S012/S012R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S012/S012R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S012/S012R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S013/S013R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S013/S013R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S013/S013R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S013/S013R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S013/S013R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S013/S013R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S014/S014R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S014/S014R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S014/S014R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S014/S014R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9599  =      0.000 ...    59.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S014/S014R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S014/S014R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S015/S015R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S015/S015R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S015/S015R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S015/S015R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S015/S015R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S015/S015R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S016/S016R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S016/S016R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S016/S016R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S016/S016R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S016/S016R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S016/S016R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S017/S017R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S017/S017R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S017/S017R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S017/S017R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S017/S017R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S017/S017R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S018/S018R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S018/S018R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S018/S018R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S018/S018R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S018/S018R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S018/S018R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S019/S019R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S019/S019R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S019/S019R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S019/S019R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S019/S019R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S019/S019R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S020/S020R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S020/S020R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S020/S020R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S020/S020R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S020/S020R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S020/S020R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S021/S021R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S021/S021R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S021/S021R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S021/S021R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S021/S021R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S021/S021R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S022/S022R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S022/S022R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S022/S022R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S022/S022R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S022/S022R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S022/S022R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S023/S023R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S023/S023R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S023/S023R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S023/S023R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S023/S023R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S023/S023R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S024/S024R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S024/S024R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S024/S024R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S024/S024R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S024/S024R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S024/S024R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S025/S025R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S025/S025R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S025/S025R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S025/S025R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S025/S025R01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S025/S025R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S026/S026R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S026/S026R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S026/S026R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S026/S026R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S026/S026R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S026/S026R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S027/S027R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S027/S027R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S027/S027R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S027/S027R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S027/S027R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S027/S027R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S028/S028R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S028/S028R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S028/S028R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S028/S028R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S028/S028R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S028/S028R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S029/S029R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S029/S029R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S029/S029R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S029/S029R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S029/S029R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S029/S029R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S030/S030R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S030/S030R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S030/S030R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S030/S030R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S030/S030R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S030/S030R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19839  =      0.000 ...   123.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S031/S031R14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S031/S031R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S031/S031R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S031/S031R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S031/S031R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S031/S031R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S032/S032R13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S032/S032R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S032/S032R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S032/S032R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S032/S032R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S032/S032R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S033/S033R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S033/S033R09.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S033/S033R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S033/S033R10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S033/S033R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S033/S033R11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S034/S034R05.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S034/S034R12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S034/S034R02.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# Used Annotations descriptions: ['T0']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S034/S034R08.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S034/S034R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Extracting EDF parameters from /Users/owalid/42/post_intership/total-perspective-vortex/files/S034/S034R07.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19679  =      0.000 ...   122.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']

# %%
def preprocess_raw(raw):
    # "Fc5.","Fc6.","Fc3.","Fc4.","Fc1.","Fc2.","C5..","C6..","C3..","C4..","C1..","C2..","Cp5.","Cp6.","Cp3.","Cp4.","Cp1.","Cp2."
    # raw = raw.pick_channels(['Fc5.', 'Fc6.', 'Fc3.', 'Fc4.', 'Fc1.', 'Fc2.', 'C5..', 'C6..', 'C3..', 'C4..', 'C1..', 'C2..', 'Cp5.', 'Cp6.', 'Cp3.', 'Cp4.', 'Cp1.', 'Cp2.'])

    # filters
    notch_freq = 60
    raw.notch_filter(notch_freq, fir_design='firwin')

    low_cutoff = 8
    high_cutoff = 40
    raw.filter(low_cutoff, high_cutoff, fir_design='firwin')

    events, event_dict = mne.events_from_annotations(raw)
    print(raw.info)
    print(event_dict)
    picks = mne.pick_types(raw.info, meg=True, eeg=True, stim=False, eog=False, exclude='bads')

    event_id = {'T1': 2, 'T2': 3, 'T3': 4, 'T4': 5}
    events, event_dict = mne.events_from_annotations(raw, event_id=event_id)
    tmin = -0.2  # Time before event in seconds
    tmax = 0.8  # Time after event in seconds
    epochs = mne.Epochs(raw, events, event_dict, tmin, tmax, proj=True, picks=picks, baseline=None, preload=True)

    # raw, events, event_dict, picks, epochs
    return raw, events, event_dict, picks, epochs

# %%
raw_train = raws_train_obj.copy()
raw_test = raw_test_obj.copy()

raw_train, events_train, event_dict_train, picks_train, epochs_train = preprocess_raw(raw_train)
raw_test, events_test, event_dict_test, picks_test, epochs_test = preprocess_raw(raw_test)
# Out:
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 1057 samples (6.606 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:   28.3s finished
# Filtering raw data in 186 contiguous segments
# Setting up band-pass filter from 8 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.2s finished
# Used Annotations descriptions: ['T1', 'T2', 'T3', 'T4', 'rest']
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 8.0 Hz
#  lowpass: 40.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >
# {'T1': 1, 'T2': 2, 'T3': 3, 'T4': 4, 'rest': 5}
# Used Annotations descriptions: ['T1', 'T2', 'T3', 'T4']
# Not setting metadata
# 2460 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 2460 events and 161 original time points ...
# 0 bad epochs dropped
# Setting up band-stop filter from 59 - 61 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 59.35
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 59.10 Hz)
# - Upper passband edge: 60.65 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 60.90 Hz)
# - Filter length: 1057 samples (6.606 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    2.6s finished
# Filtering raw data in 18 contiguous segments
# Setting up band-pass filter from 8 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 265 samples (1.656 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    0.2s finished
# Used Annotations descriptions: ['T1', 'T2', 'T3', 'T4', 'rest']
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 8.0 Hz
#  lowpass: 40.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >
# {'T1': 1, 'T2': 2, 'T3': 3, 'T4': 4, 'rest': 5}
# Used Annotations descriptions: ['T1', 'T2', 'T3', 'T4']
# Not setting metadata
# 255 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 255 events and 161 original time points ...
# 0 bad epochs dropped

# %%
def get_X_y(epochs):
    import pywt

    # Define the wavelet decomposition parameters
    wavelet = 'db10'  # Choose a wavelet (e.g., 'morl')
    level = 15  # Adjust the decomposition level as needed

    # Perform wavelet decomposition on EEG data
    coeffs = pywt.wavedec(epochs.get_data(), wavelet, level=level)
    mu_rhythm = coeffs[level] # Mu rhythm (8-13 Hz)
    beta_rhythm = coeffs[level]  # Beta rhythm (13-30 Hz)
    X = np.concatenate((mu_rhythm, beta_rhythm), axis=1)
    y = epochs.events[:, -1] - 2
    return X, to_categorical(y)

# %%
X_train, y_train = get_X_y(epochs_train)
X_test, y_test = get_X_y(epochs_test)

# %%
X_train.shape, y_train.shape
# Out:
# ((2460, 128, 90), (2460, 4))

# %%
# cnn
n_channels = X_train.shape[1]
input_window_size = X_train.shape[2]
input_shape = (1, n_channels, input_window_size)
X_train = X_train.reshape(X_train.shape[0], 1, n_channels, input_window_size)
X_test = X_test.reshape(X_test.shape[0], 1, n_channels, input_window_size)
print(X_train.shape, X_test.shape)
# Out:
# (2460, 1, 128, 90) (255, 1, 128, 90)

# %%
model = Sequential()
# Block 1: Temporal Convolution
model.add(Conv2D(8, (1, n_channels), strides=(1, 1), padding='same', use_bias=False, input_shape=input_shape))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block 2: Spacial Convolution
model.add(Conv2D(int(n_channels/2), (1, n_channels), strides=(1, 1), padding='same', use_bias=False))
model.add(BatchNormalization())
model.add(Activation('elu'))
# model.add(AveragePooling2D(pool_size=(1, 4), strides=(1, 4)))
model.add(Dropout(0.25))

# Block 3: Separable Convolution
model.add(Conv2D(8, (1, 1), strides=(1, 1), padding='same', use_bias=False))
model.add(Conv2D(16, (1, 1), strides=(1, 1), padding='same', use_bias=False))
model.add(BatchNormalization())
model.add(Activation('elu'))
# model.add(AveragePooling2D(pool_size=(1, 4), strides=(1, 4)))
model.add(Dropout(0.25))
model.add(Flatten())

# Classifier
model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 1, 128, 8)         92160
#
#  batch_normalization_3 (Batc  (None, 1, 128, 8)        32
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 1, 128, 8)         0
#
#  conv2d_5 (Conv2D)           (None, 1, 128, 64)        65536
#
#  batch_normalization_4 (Batc  (None, 1, 128, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1, 128, 64)        0
#
#  dropout_4 (Dropout)         (None, 1, 128, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 1, 128, 8)         512
#
#  conv2d_7 (Conv2D)           (None, 1, 128, 16)        128
#
#  batch_normalization_5 (Batc  (None, 1, 128, 16)       64
#  hNormalization)
#
#  activation_3 (Activation)   (None, 1, 128, 16)        0
#
#  dropout_5 (Dropout)         (None, 1, 128, 16)        0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 4)                 8196
#
# =================================================================
# Total params: 166,884
# Trainable params: 166,708
# Non-trainable params: 176
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=250, batch_size=15, validation_data=(X_test, y_test), verbose=1, shuffle=False)
loss, accuracy = model.evaluate(X_train, y_train, verbose=1)
print(f'Accuracy: {accuracy}')
print(f'Loss: {loss}')
# Out:
# Epoch 1/250
# 164/164 [==============================] - 10s 58ms/step - loss: 0.9772 - accuracy: 0.6028 - val_loss: 1.8144 - val_accuracy: 0.2078
# Epoch 2/250
# 164/164 [==============================] - 9s 57ms/step - loss: 0.9710 - accuracy: 0.5923 - val_loss: 1.8840 - val_accuracy: 0.2039
# Epoch 3/250
# 164/164 [==============================] - 9s 56ms/step - loss: 0.9767 - accuracy: 0.5833 - val_loss: 1.9004 - val_accuracy: 0.1922
# Epoch 4/250
# 164/164 [==============================] - 9s 56ms/step - loss: 0.9461 - accuracy: 0.6085 - val_loss: 1.8460 - val_accuracy: 0.2196
# Epoch 5/250
# 164/164 [==============================] - 9s 56ms/step - loss: 0.9352 - accuracy: 0.5931 - val_loss: 1.9221 - val_accuracy: 0.2196
# Epoch 6/250
# 164/164 [==============================] - 9s 56ms/step - loss: 0.9201 - accuracy: 0.6211 - val_loss: 1.9032 - val_accuracy: 0.1922
# Epoch 7/250
# 164/164 [==============================] - 9s 57ms/step - loss: 0.9308 - accuracy: 0.6110 - val_loss: 1.8961 - val_accuracy: 0.2039
# Epoch 8/250
# 164/164 [==============================] - 9s 56ms/step - loss: 0.9186 - accuracy: 0.6248 - val_loss: 1.9747 - val_accuracy: 0.1843
# Epoch 9/250
# 164/164 [==============================] - 9s 56ms/step - loss: 0.9152 - accuracy: 0.6167 - val_loss: 1.9515 - val_accuracy: 0.2196
# Epoch 10/250
# 164/164 [==============================] - 9s 56ms/step - loss: 0.8641 - accuracy: 0.6435 - val_loss: 2.0137 - val_accuracy: 0.2118
# Epoch 11/250
# 164/164 [==============================] - 10s 64ms/step - loss: 0.8830 - accuracy: 0.6382 - val_loss: 1.9286 - val_accuracy: 0.2196
# Epoch 12/250
# 164/164 [==============================] - 13s 81ms/step - loss: 0.8488 - accuracy: 0.6337 - val_loss: 1.8432 - val_accuracy: 0.2157
# Epoch 13/250
# 164/164 [==============================] - 16s 96ms/step - loss: 0.8771 - accuracy: 0.6455 - val_loss: 1.9565 - val_accuracy: 0.2196
# Epoch 14/250
# 164/164 [==============================] - 17s 104ms/step - loss: 0.8446 - accuracy: 0.6593 - val_loss: 1.9044 - val_accuracy: 0.2471
# Epoch 15/250
# 164/164 [==============================] - 16s 97ms/step - loss: 0.8419 - accuracy: 0.6634 - val_loss: 2.0515 - val_accuracy: 0.2078
# Epoch 16/250
# 164/164 [==============================] - 14s 86ms/step - loss: 0.8421 - accuracy: 0.6467 - val_loss: 2.0142 - val_accuracy: 0.2157
# Epoch 17/250
# 164/164 [==============================] - 13s 76ms/step - loss: 0.8049 - accuracy: 0.6789 - val_loss: 2.0494 - val_accuracy: 0.1882
# Epoch 18/250
# 164/164 [==============================] - 12s 75ms/step - loss: 0.7925 - accuracy: 0.6833 - val_loss: 2.0786 - val_accuracy: 0.2118
# Epoch 19/250
# 164/164 [==============================] - 19s 115ms/step - loss: 0.3471 - accuracy: 0.8699 - val_loss: 2.6235 - val_accuracy: 0.2314
# Epoch 98/250
# 164/164 [==============================] - 19s 114ms/step - loss: 0.2925 - accuracy: 0.8967 - val_loss: 2.6194 - val_accuracy: 0.2039
# Epoch 99/250
# 164/164 [==============================] - 16s 100ms/step - loss: 0.3105 - accuracy: 0.8846 - val_loss: 2.6781 - val_accuracy: 0.2196
# Epoch 100/250
# 164/164 [==============================] - 18s 109ms/step - loss: 0.3168 - accuracy: 0.8825 - val_loss: 2.5730 - val_accuracy: 0.1961
# Epoch 101/250
# 164/164 [==============================] - 17s 106ms/step - loss: 0.3006 - accuracy: 0.8833 - val_loss: 2.6163 - val_accuracy: 0.2431
# Epoch 102/250
# 164/164 [==============================] - 14s 85ms/step - loss: 0.3134 - accuracy: 0.8825 - val_loss: 2.6262 - val_accuracy: 0.2392
# Epoch 103/250
# 164/164 [==============================] - 13s 80ms/step - loss: 0.3024 - accuracy: 0.8821 - val_loss: 2.6177 - val_accuracy: 0.2000
# Epoch 104/250
# 164/164 [==============================] - 13s 81ms/step - loss: 0.3087 - accuracy: 0.8797 - val_loss: 2.6329 - val_accuracy: 0.2157
# Epoch 105/250
# 164/164 [==============================] - 14s 84ms/step - loss: 0.2706 - accuracy: 0.9008 - val_loss: 2.7044 - val_accuracy: 0.2039
# Epoch 106/250
# 164/164 [==============================] - 15s 94ms/step - loss: 0.3415 - accuracy: 0.8683 - val_loss: 2.7218 - val_accuracy: 0.1922
# Epoch 107/250
# 164/164 [==============================] - 16s 99ms/step - loss: 0.3037 - accuracy: 0.8951 - val_loss: 2.6797 - val_accuracy: 0.1765
# Epoch 108/250
# 164/164 [==============================] - 21s 128ms/step - loss: 0.2871 - accuracy: 0.8927 - val_loss: 2.6867 - val_accuracy: 0.2078
# Epoch 109/250
# 164/164 [==============================] - 29s 176ms/step - loss: 0.2933 - accuracy: 0.8943 - val_loss: 2.6976 - val_accuracy: 0.1961
# Epoch 110/250
# 164/164 [==============================] - 21s 126ms/step - loss: 0.2720 - accuracy: 0.8967 - val_loss: 2.6714 - val_accuracy: 0.2078
# Epoch 111/250
# 164/164 [==============================] - 18s 108ms/step - loss: 0.2816 - accuracy: 0.8931 - val_loss: 2.8025 - val_accuracy: 0.2000
# Epoch 112/250
# 164/164 [==============================] - 18s 111ms/step - loss: 0.2607 - accuracy: 0.9020 - val_loss: 2.6960 - val_accuracy: 0.2039
# Epoch 113/250
# 164/164 [==============================] - 21s 127ms/step - loss: 0.3239 - accuracy: 0.8801 - val_loss: 2.7221 - val_accuracy: 0.2196
# Epoch 114/250
# 164/164 [==============================] - 20s 120ms/step - loss: 0.2933 - accuracy: 0.8939 - val_loss: 2.7366 - val_accuracy: 0.2000
# Epoch 115/250
# 164/164 [==============================] - 16s 100ms/step - loss: 0.2862 - accuracy: 0.8874 - val_loss: 2.6470 - val_accuracy: 0.2000
# Epoch 116/250
# 164/164 [==============================] - 15s 92ms/step - loss: 0.2547 - accuracy: 0.9098 - val_loss: 2.6801 - val_accuracy: 0.2000
# Epoch 117/250
# 164/164 [==============================] - 22s 132ms/step - loss: 0.2937 - accuracy: 0.8878 - val_loss: 2.6774 - val_accuracy: 0.2275
# Epoch 118/250
# 164/164 [==============================] - 26s 162ms/step - loss: 0.2703 - accuracy: 0.9020 - val_loss: 2.7046 - val_accuracy: 0.2078
# Epoch 119/250
# 164/164 [==============================] - 21s 131ms/step - loss: 0.2500 - accuracy: 0.8996 - val_loss: 2.5921 - val_accuracy: 0.2196
# Epoch 120/250
# 164/164 [==============================] - 22s 133ms/step - loss: 0.2633 - accuracy: 0.9024 - val_loss: 2.6993 - val_accuracy: 0.2157
# Epoch 121/250
# 164/164 [==============================] - 17s 105ms/step - loss: 0.2660 - accuracy: 0.9008 - val_loss: 2.6850 - val_accuracy: 0.2157
# Epoch 122/250
# 164/164 [==============================] - 18s 112ms/step - loss: 0.2972 - accuracy: 0.8943 - val_loss: 2.7164 - val_accuracy: 0.2078
# Epoch 123/250
# 164/164 [==============================] - 22s 132ms/step - loss: 0.2441 - accuracy: 0.9061 - val_loss: 2.7656 - val_accuracy: 0.1961
# Epoch 124/250
# 164/164 [==============================] - 26s 162ms/step - loss: 0.2634 - accuracy: 0.9053 - val_loss: 2.7063 - val_accuracy: 0.2353
# Epoch 125/250
# 164/164 [==============================] - 18s 112ms/step - loss: 0.2753 - accuracy: 0.9085 - val_loss: 2.5995 - val_accuracy: 0.2039
# Epoch 126/250
# 164/164 [==============================] - 13s 77ms/step - loss: 0.2631 - accuracy: 0.8943 - val_loss: 2.7374 - val_accuracy: 0.2196
# Epoch 127/250
# 164/164 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.9028
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/s9/mx70pkk11bq2wl2cnrt6nfwc0000gn/T/ipykernel_41313/1757294251.py in <module>
# ----> 1 model.fit(X_train, y_train, epochs=250, batch_size=15, validation_data=(X_test, y_test), verbose=1, shuffle=False)
#       2 loss, accuracy = model.evaluate(X_train, y_train, verbose=1)
#       3 print(f'Accuracy: {accuracy}')
#       4 print(f'Loss: {loss}')
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1727                             steps_per_execution=self._steps_per_execution,
#    1728                         )
# -> 1729                     val_logs = self.evaluate(
#    1730                         x=val_x,
#    1731                         y=val_y,
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2062             self._test_counter.assign(0)
#    2063             callbacks.on_test_begin()
# -> 2064             for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2065                 self.reset_metrics()
#    2066                 with data_handler.catch_stop_iteration():
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1303         """Yields `(epoch, tf.data.Iterator)`."""
#    1304         with self._truncate_execution_to_epoch():
# -> 1305             data_iterator = iter(self._dataset)
#    1306             for epoch in range(self._initial_epoch, self._epochs):
#    1307                 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     503     if context.executing_eagerly() or ops.inside_function():
#     504       with ops.colocate_with(self._variant_tensor):
# --> 505         return iterator_ops.OwnedIterator(self)
#     506     else:
#     507       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     711             "When `dataset` is provided, `element_spec` and `components` must "
#     712             "not be specified.")
# --> 713       self._create_iterator(dataset)
#     714
#     715     self._get_next_call_count = 0
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     750             self._flat_output_types)
#     751         self._iterator_resource.op.experimental_set_type(fulltype)
# --> 752       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     753
#     754   def __iter__(self):
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3406   if tld.is_eager:
#    3407     try:
# -> 3408       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3409         _ctx, "MakeIterator", name, dataset, iterator)
#    3410       return _result
#
# KeyboardInterrupt:
